# %%
# print 'CORRECT' if i == 10
#value: 10
#Corret

i = int(input("value: "))
if ( i == 10):
    print("Correct")
# Out:
# value:  10
# Correct

# %%
# Check the password, using if and else
# Enter the password: HOPE@123
# Your password is correct

pass1 = input("Enter the password: ")
if(pass1 == "HOPE@123"):
    print("Your password is correct")
# Out:
# Enter the password:  HOPE@123
# Your password is correct

# %%
# Catagory the people by their age like children, adult, citizen, senior citizen...
# age: 20
# Adult
#-----------
#children <18, adult <30, citizen < 60, senior citizen >60 

age= int(input("age: "))
if(age < 18):
    print("Children")
elif(age < 30):
    print("Adult")
elif(age < 60):
    print("Citizen")
elif(age >= 60):
    print("Senior Citizen")
else:
    print("Please enter a proper number")
# Out:
# age:  20
# Adult

# %%
# Find whether given number is positive or negative
# Enter any number:1
# No is positive

num1 = int(input("Please Enter any number:"))
if(num1 > 0):
        print("Number is Positive")
else:
        print("Number is Negative")
# Out:
# Please Enter any number: 1
# Number is Positive

# %%
# Check whether the given number is divisible by 5
# Enter a number to check:22
# No is not divisible by 5

print("To Check if a given number is divisible by 5")
num1 = int(input("Enter any number to check: "))
if(num1%5 == 0):
        print("Number is divisible by 5")
else:
        print("Number is not divisible by 5")
# Out:
# To Check if a given number is divisible by 5
# Enter any number to check:  22
# Number is not divisible by 5
