# %%
from MFunctions import MFunction
age=int(input("Enter age of the individual"))
agecate=MFunction.age_category_r(age)
print(agecate)
# Out:
# Enter age of the individual 20
# Adult
# Adult

# %%
from MFunctions import MFunction
message1=MFunction.odd_even()
print(message1)
# Out:
# Enter a number 4
# 4 is Even Number
# Even Number

# %%
from MFunctions import MFunction
MFunction.BMI()
# Out:
# Please Enter the BMI index: 18.6
# BMI: 18.6
# Healthy Weight

# %%
from MFunctions import MFunction
MFunction.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Search Processing
# Natutal Language Processing

# %%
from MFunctions import MFunction
MFunction.Eligible()
# Out:
# Please Enter your Gender(Male/Female):  Male
# Please Enter Your age:  20
# gender:  Male
# age:  20
# NOT ELIGIBLE

# %%
from MFunctions import MFunction
MFunction.percentage()
# Out:
# Total= 468
# Average= 93.6

# %%
from MFunctions import MFunction
MFunction.triangle()
# Out:
# Area formula: (Height*Breadth)/2
# Area of Triangle:  544.0
# Height1 : 2
# Height2 : 4
# Breath : 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:  10
