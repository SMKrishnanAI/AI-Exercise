# %%
#1.Find the error in the following Python code:
# import math
# print(Math.sqrt(16))
#------------------------------------------------------
import math
print(math.sqrt(16))

#
# Error:
#      1.NameError: name 'Math' is not defined
#
# solution:
#   Change Math to math
#
# Out:
# 4.0

# %%
# #2.Find the error in the following Python code:
# def my_function():
#     x += 5
#     print(x)

# x = 10
# my_function()

def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()

#
# Error:
#      1.UnboundLocalError: cannot access local variable 'x' where it is not associated with a value
#
# solution:
#     2. change the x scope to global  global x  # Declare that we are using the global variable x
#
# Out:
# 15

# %%
# #3.x = 5
# if x = 10:
#     print("x is 10")

x = 5
if x == 10:
    print("x is 10")

#
# Error:
#      1.SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
#
# solution:
#     2. change assignment operator "=" to equality comparison operator "=="

# %%
#4.
# numbers = [5, 3, 8, 2]
# print(numbers.sort())

numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)

#
# logic error:
#      1.there is no output
#     sort() is a modifying function that modifies the list
#     it by itself is numbersa list so print(numbers. sort()) will produce nothing
#
# solution:
#     remove the print alone and the paranthesis of print
#     let numbers.sort() be in one line
#     in the following line print(numbers)
#     it by itself is numbersa list so print(numbers. sort()) will produce nothing
# Out:
# [2, 3, 5, 8]

# %%
#5.
# def square(n):
#     n * n

# print(square(4))

def square(n):
    return n * n

print(square(4))

# return statement missing
# Out:
# 16

# %%
#6.
# my_tuple = (1, 2, 3)
# my_tuple[1] = 5

my_tuple = (1, 2, 3)
#my_tuple[1] = 5
my_tuple = (1,5,3)

#
# Error
#   1.TypeError: 'tuple' object does not support item assignment
#
# solution:
#   Since Tuple is immutable, assignment cannot be done
#   we can recreate the my_tuple with new value

# %%
#7.
# name = "Alice"
# age = 25
# print("My name is %s and I am %d years old" % (name))

name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name, age))

# TypeError: not enough arguments for format string
# Solution: age has to be included which make it % (name, age)
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
# a = [1, 2, 3]
# b = [1, 2, 3]
# if a is b:
#     print("Lists are equal")

a = [1, 2, 3]
b = [1, 2, 3]
print("memory address of a:",id(a))
print("memory address of b:",id(b))
if a is b:
    print("Lists are equal")

# since id of a and b are different a is b will not be true
# hence the print statement wont be printed
# Out:
# memory address of a: 2095539066368
# memory address of b: 2095540480192

# %%
#9.
# for i in range(5, 1):
#     print(i)

for i in range(5, 1,-1):
    print(i)

# since start value is greater than stop value, this wont print any sequence
# in this case if we give a negative step it will pring
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
print(student["name"])

#
# Error : KeyError: 'Alice'
# fix : enclose the key in double quotes
# Out:
# John
